# %%
import pandas as pd

data = {
    "Name": ['Arun', 'Varun', 'Karun', 'Narun', 'Marun'],
    "Age": [28, 34, 22, 34, 28],
    "Salary": [50000, 60000, 45000, 52000, 48000],
    "City": ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']
}

df = pd.DataFrame(data)

# %%
grp=df.groupby("Age")["Salary"].sum()
grp
# Out:
# Age
# 22     45000
# 28     98000
# 34    112000
# Name: Salary, dtype: int64

# %%
grp1=df.groupby(["Age","Name"])["Salary"].sum()
print(grp1)
# Out:
# Age  Name
# 22   Karun    45000
# 28   Arun     50000
#      Marun    48000
# 34   Narun    52000
#      Varun    60000
# Name: Salary, dtype: int64
