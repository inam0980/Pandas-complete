# %%
import pandas as pd
data = {
    "Name": ['Ram', 'Inam Khan', 'Ghanshyam', 'Dhanshyam', 'Aditi', 'Jagdish', 'Raj', 'Simran'],
    "Age": [28, 34, 22, 30, 29, 40, 25, 32],
    "Salary": [50000, 60000, 45000, 52000, 49000, 70000, 48000, 58000],
    "Performance Score": [85, 90, 78, 92, 88, 95, 80, 89]
}

df=pd.DataFrame(data)

# %%
df.loc[2,"Salary"]=786786
print(df)
# Out:
#         Name  Age  Salary  Performance Score
# 0        Ram   28   50000                 85
# 1      Shyam   34   60000                 90
# 2  Ghanshyam   22  786786                 78
# 3  Dhanshyam   30   52000                 92
# 4      Aditi   29   49000                 88
# 5    Jagdish   40   70000                 95
# 6        Raj   25   48000                 80
# 7     Simran   32   58000                 89

# %%
df["Age"]=df["Age"]+10
print(df)
# Out:
#         Name  Age  Salary  Performance Score
# 0        Ram   38   50000                 85
# 1      Shyam   44   60000                 90
# 2  Ghanshyam   32  786786                 78
# 3  Dhanshyam   40   52000                 92
# 4      Aditi   39   49000                 88
# 5    Jagdish   50   70000                 95
# 6        Raj   35   48000                 80
# 7     Simran   42   58000                 89

# %%
df.loc[df['Salary']>60000,"Salary"] +=1
print(df)
# Out:
#         Name  Age  Salary  Performance Score
# 0        Ram   38   50000                 85
# 1      Shyam   44   60000                 90
# 2  Ghanshyam   32  786787                 78
# 3  Dhanshyam   40   52000                 92
# 4      Aditi   39   49000                 88
# 5    Jagdish   50   70001                 95
# 6        Raj   35   48000                 80
# 7     Simran   42   58000                 89

# %%
df.loc[(df['Age']>40) & (df['Salary']<70000),'Age']=0
print(df)
# Out:
#         Name  Age  Salary  Performance Score
# 0        Ram   38   50000                 85
# 1      Shyam    0   60000                 90
# 2  Ghanshyam   32  786787                 78
# 3  Dhanshyam   40   52000                 92
# 4      Aditi   39   49000                 88
# 5    Jagdish   50   70001                 95
# 6        Raj   35   48000                 80
# 7     Simran    0   58000                 89
