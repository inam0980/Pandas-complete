# %%
import pandas as pd
data = {
    "Name": ['Ram', 'Shyam', 'Ghanshyam', 'Dhanshyam', 'Aditi', 'Jagdish', 'Raj', 'Simran'],
    "Age": [28, 34, 22, 30, 29, 40, 25, 32],
    "Salary": [50000, 60000, 45000, 52000, 49000, 70000, 48000, 58000],
    "Performance Score": [85, 90, 78, 92, 88, 95, 80, 89]
}

df=pd.DataFrame(data)

# %%
df["Bonus"]=df['Salary']*.10
df
# Out:
#    Employe_ID       Name  Age  Salary  Performance Score   Bonus
# 0          20        Ram   28   50000                 85  5000.0
# 1          30      Shyam   34   60000                 90  6000.0
# 2          40  Ghanshyam   22   45000                 78  4500.0
# 3          23  Dhanshyam   30   52000                 92  5200.0
# 4          43      Aditi   29   49000                 88  4900.0
# 5          34    Jagdish   40   70000                 95  7000.0
# 6          55        Raj   25   48000                 80  4800.0
# 7          53     Simran   32   58000                 89  5800.0

# %%
df.insert(3,"Extra BOnus",df["Salary"]*0.10)

# %%
print(df)
# Out:
#    Employe_ide  Employe_ID       Name  Extra BOnus  Age  Salary  \
# 0           20          20        Ram       5000.0   28   50000
# 1           30          30      Shyam       6000.0   34   60000
# 2           40          40  Ghanshyam       4500.0   22   45000
# 3           23          23  Dhanshyam       5200.0   30   52000
# 4           43          43      Aditi       4900.0   29   49000
# 5           34          34    Jagdish       7000.0   40   70000
# 6           55          55        Raj       4800.0   25   48000
# 7           53          53     Simran       5800.0   32   58000
#
#    Performance Score   Bonus
# 0                 85  5000.0
# 1                 90  6000.0
# 2                 78  4500.0
# 3                 92  5200.0
# 4                 88  4900.0
# 5                 95  7000.0
# 6                 80  4800.0
# 7                 89  5800.0
